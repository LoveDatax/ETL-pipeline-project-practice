# %%
import pandas as pd
import logging
import os
from pipeline import extract, transform, load
logging.basicConfig(format = '%(levelname)s:%(message)s', level = logging.DEBUG)

# %%
wine_data = extract('winemag-data_first150k.csv')
wine_data
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
df = transform(wine_data)
df
# Out:
# C:\Users\User\Documents\Repositories\ETL-pipeline-project-practice\pipeline.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data.fillna({'price': raw_data['price'].mean(),
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df = transform(wine_data)
#       2 df
#
# File ~\Documents\Repositories\ETL-pipeline-project-practice\pipeline.py:11, in transform(raw_data)
#       7 raw_data = raw_data[['country', 'description', 'points', 'price', 'region_1', 'region_2']]
#       8 raw_data.fillna({'price': raw_data['price'].mean(),
#       9                  'region_1' : 'missing',
#      10                  'region_2' : 'N/A'}, inplace = True)
# ...
